# %% [markdown]
# # Numpy를 이용한 plot 기능

# %%
# %matplotlib inline
import numpy as np
points = np.array([[1,1], [1,2], [1,3], [2,1], [2,2], [2,3], [3,1], [3,2], [3,3]])
p = np.array([2.5, 2])
import matplotlib.pyplot as plt
plt.plot(points[:,0], points[:,1], "ro")
plt.plot(p[0], p[1], "bo")

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0, 5, 10)
y = x**2
plt.plot(x, y);

# %%
x = np.linspace(0, 10, 20)
y = x**2.0
plt.plot(x, y, "bo-", linewidth=3, markersize=5);

# %%
plt.plot(x, y, "gs-", linewidth=1, markersize=3);

# %%
x = np.linspace(0, 10, 20)
y1 = x**2.0
y2 = x**1.5
plt.plot(x, y1, "bo-", linewidth=2, markersize=12, label="First")
plt.plot(x, y2, "gs-", linewidth=2, markersize=12, label="Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
x = np.logspace(-1, 1, 20)
y1 = x**2.0
y2 = x**1.5
plt.plot(x, y1, "bo-", linewidth=2, markersize=5, label="First")
plt.plot(x, y2, "gs-", linewidth=2, markersize=5, label="Second")
plt.xlabel("X")
plt.ylabel("Y")
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left")
plt.savefig("mplot.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.standard_normal(size=1000)
plt.hist(x)
# Out:
# (array([  4.,  44.,  99., 193., 261., 234., 124.,  29.,   9.,   3.]),
#  array([-3.06304614, -2.39351703, -1.72398792, -1.05445881, -0.38492969,
#          0.28459942,  0.95412853,  1.62365764,  2.29318675,  2.96271586,
#          3.63224497]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x, density=True)
# Out:
# (array([0.00597435, 0.06571783, 0.14786512, 0.2882623 , 0.38982622,
#         0.34949937, 0.18520479, 0.04331402, 0.01344228, 0.00448076]),
#  array([-3.06304614, -2.39351703, -1.72398792, -1.05445881, -0.38492969,
#          0.28459942,  0.95412853,  1.62365764,  2.29318675,  2.96271586,
#          3.63224497]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.randn(1000)
plt.hist(x)
# Out:
# (array([  2.,  13.,  54., 156., 267., 278., 139.,  77.,  12.,   2.]),
#  array([-3.51370154, -2.8213731 , -2.12904465, -1.4367162 , -0.74438776,
#         -0.05205931,  0.64026914,  1.33259758,  2.02492603,  2.71725447,
#          3.40958292]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.rand(30)
y = np.random.rand(30)
colors = np.random.rand(30)
shape = np.pi * (np.random.rand(30)*20) **2
plt.scatter(x, y, s=shape, c = colors, marker='*', alpha=0.7)
plt.show()
