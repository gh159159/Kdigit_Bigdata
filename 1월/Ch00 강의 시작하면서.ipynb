# %% [markdown]
# # 강사 소개
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 강의 목표
# * Python을 이용하여 스스로 기본적인 프로그램을 작성할 수 있다
# * Python으로 작성된 코드를 읽고 코드의 흐름을 이해할 수 있다

# %% [markdown]
# # 교재
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 교육 내용
# ![image.png](data:image/png;base64,...)
