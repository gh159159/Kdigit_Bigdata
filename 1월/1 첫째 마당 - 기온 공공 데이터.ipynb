# %% [markdown]
# #Ch01-1기온 데이터 분석 시작하기

# %% [markdown]
# ##기온 공공데이터 살펴보기
#
# 기상청은 기상자료개방포털 홈페이지를 통해 기상 관련 데이터를 무료로 제공
#
# \[[기상자료개방포털](https://data.kma.go.kr)\]
#
# 상단 메뉴에서, **기후통계분석/통계분석/기온분석**을 선택합니다.
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# 검색조건 메뉴에서 지역/지점은 "부산"을 선택하고 기간은 "1907년 10월 1일부터 어제"까지로 선택한 후 검색 버튼을 클릭하세요. 검색이 완료된 후 CSV 버튼을 클릭하여 해당 데이터를 csv 파일 형태로 다운로드 합니다.
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# 위에서 'CSV' 버튼을 클릭한 후 기다리시면 해당 지역의 설정 기간 동안의 기온 정보를 담은 csv 파일이 다운로드 됩니다.

# %% [markdown]
# ##CSV 파일이란
# 다운로드 받은 파일은 더블 클릭하여 excel로 열어서 데이터를 확인하세요.

# %% [markdown]
# ##데이터 분석에 필요한 환경 만들기
# 구글 colab 환경에 진행하겠습니다.

# %% [markdown]
# #Ch01-2 부산의 기온 데이터 분석하기

# %% [markdown]
# ##1. CSV 파일에서 데이터 읽어 오기
#
# - ```csv.reader()``` : CSV 파일에서 데이터 읽어오는 함수
# - ```csv.writer()``` : CSV 파일에 데이터를 저장하는 함수
#
# 위에서 다운로드 받은 CSV 파일을 더블 클릭하여 excel로 열어서 내용을 살펴보면 <font color=blue>첫 번째 행부터 여섯 번째 행은 이 파일에 대한 간략한 설명이 있고</font> 일곱 번째 행은 실 데이터와 구분하기 위해 빈 행이 있습니다. 1행 부터 7 행까지는 실제 데이터가 아니므로 삭제하십시요.
#
# ![image.png](data:image/png;base64,...)
#
# 위와 같이 변경 후 파일의 이름을 '부산'으로 변경하여 저장하십시요. 그리고 이 '부산.csv' 파일을 colab 환경에서 인식할 수 있도록 몇 가지 작업을 하겠습니다. 강사의 안내에 따라 주세요.

# %% [markdown]
# 코랩 화면의 왼쪽 위 구석을 보시면 아래와 같은 메뉴 아이콘이 보입니다.
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# 폴더 모양의 아이콘을 클릭하세요. 그리고 잠시 기다리시면 아래와 같은 모습을 보실 수 있습니다.
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# 원도우(운영체제)의 탐색기에서 앞서 생성한 '부산.csv' 파일을 드래그 앤 드랍으로 'sample_data' 폴더 **옆으로** 가져다 놓습니다. 그려면 PC에 있는 '부산.csv'일 코랩 공간으로 복사 됩니다.
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
#
#
# <br>
#
# <font color=red>**주의 사항**</font>
#
# 코랩 공간으로 복사된 파일은 코랩의 해당 웹 페이지가 종료되면 파일도 같이 삭제됩니다.

# %% [markdown]
# '부산.csv' 파일에서 데이터를 읽어 오는 코드를 작성해 보겠습니다.

# %%
import csv

# open() 함수를 이용하여 파일을 오픈하는데
# open() 함수의 두 번째 인자 'r'은 파일을 읽기 모드로 오픈하겠다는 의미

f = open('서울.csv', 'r')
data = csv.reader(f)
print(data)
f.close()

# %% [markdown]
# 위 코드 셀에서
# - 1번 라인, ```import csv```는 csv 모듈을 불러 옴
# - 2번 라인, ```f=open('부산.csv', 'r')```은 csv 파일(부산.csv)을 열어서 파일 핸들러를 f에 저장
# - 3번 라인, ```data=csv.reader(f)```는 파일 핸들러 ```f```를 ```csv.reader()```함수에 전달해서 '부산.csv' 파일을 핸들링 할 수 있는 객체를 ```data```에 할당.

# %% [markdown]
# ##2. 데이터 출력하기

# %% [markdown]
# ```python
# import csv
# f = open('서울.csv', 'r', encoding='cp949')
# data = csv.reader(f)
#
# for row in data:
#   print(row)
#
# f.close()
# ```
#
# 위 코드에 보인 ```f=open('서울.csv', 'r', endocing='cp949')```에 대해 살펴 보겠습니다. ```open()```함수의 두 번째 인자 'r'의 의미는 파일을 여는데 '읽기 모드'로 열겠다는 뜻입니다. 세 번째 인자에서 ```cp949```의 의미는 Window의 한글 인코딩 방식으로 읽어 오겠다는 뜻입니다. 세 번째 인자의 의미는 일단 여기서 크게 중요하지 않습니다. 위 코드 블록을 실행 시켜서 결과를 확인하세요.

# %%
import csv
f = open('서울.csv', 'r', encoding='cp949')
data = csv.reader(f)

for row in data:
  print(row)

f.close()
# 꽤 많은 데이터를 출력하기 때문에 시간이 다소 걸립니다.
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ['\t2010-05-10', '108', '16.1', '12.7', '20.9']
# ['\t2010-05-11', '108', '12.9', '10.5', '17']
# ['\t2010-05-12', '108', '13.8', '8.7', '19.6']
# ['\t2010-05-13', '108', '16', '10.2', '21.9']
# ['\t2010-05-14', '108', '18', '12.1', '23.7']
# ['\t2010-05-15', '108', '17', '12.9', '21.9']
# ['\t2010-05-16', '108', '18.2', '12.6', '25.1']
# ['\t2010-05-17', '108', '20.3', '14.4', '27']
# ['\t2010-05-18', '108', '17.3', '15', '19.4']
# ['\t2010-05-19', '108', '17.1', '14.5', '20.9']
# ['\t2010-05-20', '108', '19.5', '13.6', '25.4']
# ['\t2010-05-21', '108', '22.1', '14.9', '28.6']
# ['\t2010-05-22', '108', '20.1', '15.7', '25.5']
# ['\t2010-05-23', '108', '16.1', '14.6', '18.1']
# ['\t2010-05-24', '108', '13.1', '12.2', '15.8']
# ['\t2010-05-25', '108', '14.9', '12.1', '18.8']
# ['\t2010-05-26', '108', '17.4', '14', '21.7']
# ['\t2010-05-27', '108', '17.4', '11.5', '24']
# ['\t2010-05-28', '108', '17.3', '14.5', '20.4']
# ...

# %% [markdown]
# #####여기서 잠깐!
# 위 코드를 실행해서 얻은 출력 결과 데이터를 꼼꼼하게 살펴 보겠습니다.
#
# - 각 행의 데이터가 대괄호([])로 둘러싸여 있음, 즉 리스트!
# - 각 행, 리스트 데이터의 각 요소가 작은 따옴표로 둘러싸여 있음, 즉 문자열!
# - 누락된 데이터가 있음, 1967년 2월 19일과 1973년 10월 16일 데이터를 확인해보세요.

# %%
import csv
# open()함수에서 읽기 모드를 나타내는 배개변수 값 'r' 생략하면 '읽기 모두'!
f = open('서울.csv', encoding='cp949')
data = csv.reader(f)

# 각 요소는 ['\t2022-03-30', '159', '14', '9.8', '16.2'] 이런 형태
for row in data:
  if row[0] == "\t1967-02-19" or row[0] =="\t1973-10-16":
    print(row)

f.close()
# Out:
# ['\t1967-02-19', '108', '-1.7', '', '']
# ['\t1973-10-16', '108', '12.3', '', '']

# %% [markdown]
# 1967년 2월 19일 데이터를 보면 평균 기온 2.7도는 기록되어 있으나 최저기온과 최고 기온 데이터가 누락되어 있음을 알 수 있습니다.

# %% [markdown]
# ##3. 헤더 확인하기

# %%
import csv
f = open('서울.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv
f = open('서울.csv', encoding='cp949')
data = csv.reader(f)

# 첫번째 행을 읽어와서 header에 할당
header = next(data)
print(header)
# 그 다음 행을 읽어와서 first_row에 할당
first_row = next(data)
print(first_row)
f.close()

# %% [markdown]
# <font color=blue>```next()```함수는 ```data```의 한 행 데이터를 반환 후 ```data```에서 그 행을 삭제 한다.</font>

# %% [markdown]
# ## Quiz
# `max()`를 사용하지말고 최대 값을 찾으시오.

# %%
lst = [1, 2, 3, -2, 10, -5, 7]

# %%
max_num = -100000

for element in lst:
  if element > max_num:
    max_num = element

print(max_num)
# Out:
# 10

# %% [markdown]
# ##Quiz
# `min()`을 사용하지말고 최소 값을 찾으시오.

# %%
min_num = 100000

for element in lst:
  if element < min_num:
    min_num = element

print(min_num)
# Out:
# -5

# %% [markdown]
# ##4. 기온 공공 데이터에 질문하기
# 엑셀을 이용하여 '부산.csv' 파일을 열어서 데이터를 쭉 살펴 보십시요. 이 데이터들, 다소 거창하게 표현해서 이런 '빅데이터'에서 무엇을 찾을 수 있을까요? 다른 표현으로 "무엇이 궁금합니까?"
#
# - 부산에서 가장 더웠던 날은 언제이고 얼마나 더웠을까?
# - 일교차가 가장 큰 날은 1년 중 언제였을까?
# - 한달 동안 최저 평균 기온이 가장 낮은 달은 12월? 1월? 2월?
# - 가장 덥다고 알려진 대구 보다 부산이 더 더운 날은 1년 중 몇일이나 될까?

# %% [markdown]
# #Ch01-3 부산이 가장 더웠던 날은 언제였을까요?

# %% [markdown]
# ##<font color=blue>1. 질문 다음기</font>
# **"부산이 가장 더웠던 날은 언제였을까? 얼마나 더웠을까?"**
# 위 질문에 대해 생각해 보겠습니다.
#
# - '가장 더웠던 날'의 기준은? 덥다는 것은 기온, 습도, 풍속 등 다양한 요소에 의해 결정됨. → **"기상 관측 이래, 부산의 최고 기온이 가장 높았던 날은 언제였고 몇 도였을까?**

# %%
# Python Review
lst = [1, 2, 8, 1]
max_temp = max(lst)
lst.index(max_temp)
print('최고값', max_temp)
print(f'리스트에서 최고값의 인덱스:{max_temp}')
# Out:
# 최고값 8
# 리스트에서 최고값의 인덱스:8

# %% [markdown]
# ##2. 문제 해결 방법 구상하기
#
# '부산.csv' 파일이 가지고 있는 데이터 중 위 질문과 관계된 데이터는 날자와 최고기온입니다.
# ![image.png](data:image/png;base64,...)
#
#   1. 전체 데이터('부산.csv')를 읽어 들임.
#   2. 순차적으로 데이터(행)를 읽어서 최고 기온을 확인
#   3. 최고 기온이 가장 높았던 날짜의 해당 기온 데이터를 저장
#   4. 최종 저장된 날자와 최고 기온 값을 출력

# %% [markdown]
# ##3. 파이썬 코드로 구상한 방법을 구현하기

# %% [markdown]
# ```data```의 각 행은 리스트 형이며 리스트 형 데이터의 마지막 요소가 최고 기온 정보를 담고 있는 데이터였습니다. 그런데 이 데이터가 문자열 형으로 표현되어 있기 때문에 숫자형 데이터로 변경할 필요가 있습니다.

# %%
import csv
f = open('서울.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)       # header 제거

max_temp = -999
max_data = ''

for row in data:
  #최고 기온 정보는 행(리스트)의 맨 마지막 요소.
  if row[-1] == '':           # 맨 마지막 요소가 누락되었다면
    row[-1] = -1000           # 존재 할 수 없는 최고 기온.
  else:
    row[-1] = float(row[-1])    # 문자열 형 -> 숫자형으로 변환
  if max_temp < row[-1]:
    max_temp = row[-1]
    max_date = row[0]

f.close()
print("서울의 최고 기온이 가장 높았던 날은 "\
      + max_date +"일이며 "+ str(max_temp) +"도였습니다.")
# Out:
# 서울의 최고 기온이 가장 높았던 날은 	2018-08-01일이며 39.6도였습니다.

# %%
import csv
f = open('서울.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)       # header 제거

max_temp = -999
max_data = ''

DAY_MAX_TEMP = -1         # 인덱스를 의미가 통하는 이름으로 변경
DATE = 0

for row in data:
  if row[DAY_MAX_TEMP] == '':           #최고 기온 정보는 행(리스트)의 맨 마지막 요소. 누락되었다면
    row[DAY_MAX_TEMP] = -1000           # 존재 할 수 없는 최고 기온.
  else:
    row[DAY_MAX_TEMP] = float(row[DAY_MAX_TEMP])    # 문자열 형으로 표현된 최고 기온을 숫자형 데이터로 변환하여 저장

  if max_temp < row[DAY_MAX_TEMP]:      # 기존에 파악한 최고 기온보다 더 높은 최고 기온 값이 있다면
    max_temp = row[DAY_MAX_TEMP]              # 최고기온(max_temp)를 새롭게 찾은 더 높은 최고 기온 값으로 갱신
    max_date = row[DATE]               # 해당 날자 기록

f.close()
print("기상 관측 이래 서울의 최고 기온이 가장 높았던 날은 " + max_date +"일이며 "+ str(max_temp) +"도였습니다.")
# Out:
# 기상 관측 이래 서울의 최고 기온이 가장 높았던 날은 	2018-08-01일이며 39.6도였습니다.

# %% [markdown]
# 위 코드의 출력,
# ```
# 기상 관측 이래 서울의 최고 기온이 가장 높았던 날은     2016-08-14일이며 37.3도였습니다
# ```
# 중간에 빈공간이 들어간 이유는 ?
#
# ##### Quiz
# 빈공간을 제거하여 출력할 수 있도록 코드를 수정해 보세요.
#
# **(2023년 5월 강의에 한해, 제일 먼저 코드를 완성하신 분께 커피 삽니다.)**

# %% [markdown]
# 아래 코드를 보지 마시고 직접 작성해 보세요.

# %% [markdown]
# 이 글을 읽으셨다면 코드를 보려고한 의도가 있다고 판단해도 될까요?

# %% [markdown]
# 어어~ 진짜로 보시려고 하네요

# %% [markdown]
# 그러시면 코딩 실력이 안들어요.

# %% [markdown]
# 힌트는 한 행 데이터가
# ```python
# ['\t2023-03-27', '159', '11.3', '7.3', '16']
# ```
# 위와 같은 형태라는 점!
#
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %%
import csv
f = open('부산.csv')
data = csv.reader(f)
header = next(data)

max_temp = -999
max_data = ''

for row in data:
  if row[-1] == '':
    row[-1] = -1000           # 존재 할 수 없는 최고 기온.
  else:
    row[-1] = float(row[-1])    # 문자열 형으로 표현된 최고 기온을 숫자형 데이터로 변환하여 저장

  if max_temp < row[-1]:
    max_date = row[0].replace('\t','')   #'\t2023-03-11'
    max_temp = row[-1]

f.close()
print("기상 관측 이래 부산의 최고 기온이 가장 높았던 날은 " + max_date +"일이며 "+ str(max_temp) +"도였습니다.")
# Out:
# 기상 관측 이래 부산의 최고 기온이 가장 높았던 날은 2016-08-14일이며 37.3도였습니다.
