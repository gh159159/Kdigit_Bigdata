# %% [markdown]
# #Ch01 연습문제

# %% [markdown]
# ##문제1
# 다음 중 식별자로 사용할 수 없는 것은 모두 고르세요?
#   - (1) \_\_nice_car\_\_
#   - (2) name
#   - (3) $5
#   - (4) 21try
#   - (5) For

# %% [markdown]
# ###풀이1-1

# %%
__nice_car__ = '그랜저'
name = '김성필'
For = 'you'

# %%
$5 = 10
# Out:
#   File "<ipython-input-2-9f5ddb92b773>", line 1
#     $5 = 10
#     ^
# SyntaxError: invalid syntax

# %%
21try = '열심히 해~'
# Out:
#   File "<ipython-input-4-34074e2e29a1>", line 1
#     21try = '열심히 해~'
#      ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## 문제2
# `print()` 함수를 **한 번만** 사용하여 다음과 같이 출력되도록 코드를 작성하시오.
#
# ```
# - 거위의 꿈 -
# 난 꿈이 있었죠
# 버려지고 찢겨 남루하여도
# 내 가슴 깊숙이 보물과 같이 간직했던 꿈
# ```

# %%
print("-거위의 꿈-\n", '난 꿈이 있어죠\n', "버려지고 찢겨 남루하여도\n", "내 가슴 깊숙이 보뭄과 같이 간직했던 꿈\n")
# Out:
# -거위의 꿈-
#  난 꿈이 있어죠
#  버려지고 찢겨 남루하여도
#  내 가슴 깊숙이 보뭄과 같이 간직했던 꿈

# %% [markdown]
# ###풀이 2-1

# %%
print('- 거위의 꿈 -\n난 꿈이 있었죠\n버려지고 찢겨 남루하여도\n내 가슴 깊숙이 보물과 같이 간직했던 꿈')
# Out:
# - 거위의 꿈 -
# 난 꿈이 있었죠
# 버려지고 찢겨 남루하여도
# 내 가슴 깊숙이 보물과 같이 간직했던 꿈

# %% [markdown]
# ##문제3
# `print()` 함수를 **두 번 사용**하여 다음과 같이 출력되도록 코드를 작성하시오.
#
# ```
# 김    성필, 김    민재
# ```

# %% [markdown]
# ####풀이 3-1

# %%
print('김\t성필', end=', ')
print('김\t민재')
# Out:
# 김	성필, 김	민재
