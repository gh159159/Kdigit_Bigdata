# %% [markdown]
# #Ch02 연습문제

# %% [markdown]
# ##문제1
# 아래와 같이 코드를 작성했습니다. 변수 `x`에 저장된 값과 그 값의 데이터 형(type)을 출력하는 코드를 작성하시오.
#
# ```python
# x = '9'
# ```

# %% [markdown]
# ###풀이1-1
# ```python
# x = '9'
# print(x)
# print(type(x), x)
# ```

# %%
x = '9'
print(type(x))
print(x)
# Out:
# <class 'str'>
# 9

# %% [markdown]
# ##문제2
# 아래와 같이 코드를 작성했습니다. `i_data`에 저장된 값과 `i_data`의 데이터 형을 출력하는 코드를 작성하세요.
# ```python
# i_data = 8086
# ```

# %% [markdown]
# ###풀이 2-1

# %%
i_data = 8086
print(i_data)
print( type(i_data) )
# Out:
# 8086
# <class 'int'>

# %% [markdown]
# ##문제 3
# `print()`함수를 **한 번만** 사용하여 아래와 같이 출력되도록 코드를 작성하세요.
#
# ```
# 내 꿈은 '멋진 집'을 갖는 거야!
# ```

# %% [markdown]
# ###풀이 3-1

# %%
print("내 꿈은 '멋진 집'을 갖는 거야!")
# Out:
# 내 꿈은 '멋진 집'을 갖는 거야!

# %% [markdown]
# ###풀이 3-2

# %%
print('내 꿈은 \'멋진 집\'을 갖는 거야!')
# Out:
# 내 꿈은 '멋진 집'을 갖는 거야!

# %% [markdown]
# ##문제 4
# 아래에 미완성의 코드를 보이고 있습니다.
#
# ```python
# you = '너'
# me = '나'
#
# print()
# ```
#
# `print()`함수의 매개변수로 `you`, `me`을 활용하여 아래와 같이 출력되도록 코드를 완성하세요.
#
# ```
# 너와 나는...!
# ```
# 띄어쓰기는 '와'와 '나' 사이에 한번만 들어갔습니다.

# %% [markdown]
# ###풀이 4-1

# %%
you = '너'
me = '나'

print(you + '와 ' + me + '...!')
print(you + '와', me + '...!')
# Out:
# 너와 나...!
# 너와 나...!

# %% [markdown]
# ###풀이 4-2

# %%
you = '너'
me = '나'

print(f'{you}와 {me}는...!')
# Out:
# 너와 나는...!

# %% [markdown]
# ##문제 5
# 다음과 같은 문자열 데이터가 있습니다.
#
# ```python
# lyric = """
# 긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
# 노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
# 잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까"""
# print(lyric)
# ```
#
# `lyric`의 29번째(인덱스 28)글자 하나만 출력하는 코드를 작성하세요.

# %% [markdown]
# ###풀이 5-1

# %%
lyric = """
긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까"""

print(lyric[28])

# %% [markdown]
# 공백 문자가 출력되었습니까?

# %%
print(lyric[:28])
# Out:
# 긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어

# %%
print(lyric[29:])
# Out:
# 노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
# 잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까

# %%
print(lyric[1:32])
# Out:
# 긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
# 노랗게

# %% [markdown]
# ##문제 6
# 문제 5의 `lyric`는 문자열 데이터를 저장하고 있습니다. 이 문자열 데이터의 일부 즉, **"노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도"**만 분리해서 변수 `lyric_part`에 저장하고 `lyric_part`의 값을 출력(print)하는 코드를 작성하세요.

# %% [markdown]
# ###풀이 6-1

# %%
lyric_part = lyric[29:59]     # 29, 30, 31, ..., 58
print(lyric_part)
# Out:
# 노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도

# %%
#여기서 원하는 문자열만을 슬라이싱 하기 위한 인덱스는 `29, 30, 31, ..., 58`, 즉 [29:59]임
lyric[29:60]
# Out:
# '노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도\n'

# %%
# 인덱스 59 위치의 문자는 '\n'임.
lyric[60]
# Out:
# '잡'

# %% [markdown]
# ###풀이 6-2

# %%
start_idx = lyric.find("노랗게")
end_idx = lyric.find("잡지")

lyric_part = lyric[ start_idx:end_idx-1 ]
print(lyric_part)
# Out:
# 노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도

# %% [markdown]
# ##문제 7
# 문제 5의 `lyric`에는 문자열 데이터가 저장되어 있습니다.
# - 맨 마지막 (한) 글자만 추출하여 출력하는 코드를 작성하세요.
# - 맨 마지막 두 글자만 추출하여 출력하는 코드를 작성하세요.
# - 맨 마지막 세 글자만 추출하여 출력하는 코드를 작성하시오.
#
#
# 여기서 '글자'는 공백문자도 '글자'라고 생각하셔야 합니다.

# %% [markdown]
# ###풀이 7-1

# %%
print( lyric[-1] )
# Out:
# 까

# %%
print( lyric[-2:] )
# Out:
# 뭘까

# %%
print( lyric[-3:] )
# Out:
#  뭘까

# %% [markdown]
# 출력 결과는 ' 뭘까'입니다. 출력 결과의 첫 글자는 눈에 보이지 않는 공백 문자(스페이스)가 붙어 있습니다.

# %%
print( lyric[-4:] )
# Out:
# 윤 뭘까

# %% [markdown]
# ## 문제 8
# 문제 5~7까지 사용된 `lyric`에 저장된 문자열 데이터는 아래와 같습니다.
#
# ```python
# lyric = """
# 긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
# 노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
# 잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까"""
# ```
#
# `lyric1`를 정의 하겠습니다.
#
# ```python
# lyric1 = """긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
# 노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
# 잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까
# """
# ```
# 이전 문제5~7까지 사용했던 `lyric`과  `lyric1`에 저장된 문자열 데이터는 무엇이 다른지 생각해 보십시요.
#
# 질문입니다.
# -  `lyric`이 가지고 있는 문자열 데이터의 첫번째(인덱스 0) 값과  `lyric1`이 가지고 있는 문자열 데이터의 첫번째(인덱스 0) 값을 각각 출력하는 코드를 작성하세요.
# -  `lyric`이 가지고 있는 문자열 데이터의 맨 마지막 값과  `lyric1`이 가지고 있는 문자열 데이터의 맨 마지막 값을 각각 출력하는 코드를 작성하세요.

# %% [markdown]
# ###풀이 8 - 1

# %%
lyric = """
긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까"""

lyric1 = """긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까
"""
# 맨 첫번째 값 출력
print('---------')
print(lyric[0])
print(lyric1[0])          # '긴'

# 맨 마지막 값 출력
print(lyric[-1])          # '까'
print(lyric1[-1])
print('---------')
# Out:
# ---------
#
#
# 긴
# 까
#
#
# ---------

# %% [markdown]
# ## 문제 9
# 다음과 같이 코드를 작성했습니다.
#
# ```python
# fname = '김성필'
# sname = '김민재\n'
# ```
#
#  - (1) `fname`의 값과 `sname`의 값을 한 줄에 출력하는 코드를 작성하시오.
#  - (2) `fname`의 길이와 `sname`의 길이를 출력하는 코드를 작성하시오.

# %% [markdown]
# ###풀이 9-(1)-1

# %%
# (1)-1

fname = '김성필'
sname = '김민재\n'

print(fname, sname)
# Out:
# 김성필 김민재

# %%
# (1) - 2
print(fname +', '+ sname)
# Out:
# 김성필, 김민재

# %% [markdown]
# ###풀이 9-(2)-1

# %%
print( len(fname) )
print( len(sname) )
# 개행문자('\n')도 문자입니다. 화면(모니터)에 출력할 때 실제 보이는 것이 아니라 줄을 바꾸라는 명령으로 해석됩니다.
# Out:
# 3
# 4

# %% [markdown]
# ##문제 10
# 10을 3으로 나누었을 때 목과 나머지를 계산해서 출력(print)하는 코드를 한 줄로 완성하시오.

# %% [markdown]
# ###풀이 10-1

# %%
print(10//3, 10%3)
# Out:
# 3 1

# %%
print('목 :', 10//3, '\n너머지 :', 10%3)
# Out:
# 목 : 3
# 너머지 : 1

# %% [markdown]
# ## 문제 11
# 다음과 같은 코드가 주어졌습니다.
# ```python
# a = 1
# b = '9'
# ```
#
# `a`와 `b`를 가지고 적절하게 연산하여 그 결과가 숫자 10이 되도록 코드를 작성하세요.

# %% [markdown]
# ###풀이 11-1

# %%
a = 1
b = '9'

c = a + int(b)
print( c )
# Out:
# 10

# %%
a = 1
b = '9'

c = a + float(b)
print( c )
# Out:
# 10.0

# %% [markdown]
# ## 문제 12
# 현재 온도를 측정하니 25도씨이네요. 그래서 아래와 같이 출력하려고 합니다.
#
# ```
# 온도는 25도씨입니다
# ```
# 아래 주어진 코드를 완성하세요.
# ```python
# temperature = 25
# print()
# ```

# %% [markdown]
# ###풀이 12-1

# %%
temperature = 25
print('온도는 ' + str(temperature) + '도씨입니다.')
# Out:
# 온도는 25도씨입니다.

# %%
# 위 코드와 비교
print('온도는 ' + str(temperature), '도씨입니다.')
# Out:
# 온도는 25 도씨입니다.

# %% [markdown]
# ## 문제 13
# 아래 미완성의 코드를 제시합니다.
#
# * (1) 아래 코드가 실행 되었을 때 다음과 같이 출력되도록 코드를 **한 줄만** 수정하세요.
# ```
# 영희의 수학 점수는 88.32점이고 성필이의 국어 점수는 92.78점입니다!
# ```
# * (2) 아래 코드가 실행 되었을 때 다음과 같이 출력되도록 코드를 **한 줄만** 수정하세요.
# ```
# 영희의 수학 점수는 88.3점이고 성필이의 국어 점수는 92.8점입니다!
# ```
#
# ```python
# y_math = 88.3
# s_kor = 92.7
# print(''.format(y_math, s_kor)
# ```

# %% [markdown]
# ###풀이 13-(1)-1

# %%
y_math = 88.32
s_kor = 92.78
print( '영희의 수학 점수는 {}점이고 성필이의 국어 점수는 {}점입니다!'.format(y_math, s_kor) )
# Out:
# 영희의 수학 점수는 88.32점이고 성필이의 국어 점수는 92.78점입니다!

# %% [markdown]
# ###풀이 13-(1)-2

# %%
y_math = 88.32
s_kor = 92.78
print( '영희의 수학 점수는 {:.1f}점이고 성필이의 국어 점수는 {:.1f}점입니다!'.format(y_math, s_kor) )
# Out:
# 영희의 수학 점수는 88.3점이고 성필이의 국어 점수는 92.8점입니다!

# %% [markdown]
# ##문제 14
# 다음과 같은 문자열 데이터가 있습니다.
#
# ```python
# lyric = """긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
# 노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
# 잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까
# 친구들이 이런 말을 해 넌 너무 튀어 보이려 한다고
# 하지만 난 그런 말 신경안써 난 튀어 보이는게 정말 좋아
# 난 언제나 나를 믿고 있어 언젠가는 이뻐질 거라고
# 그래서 난 포기 하지 않아 나는 정말로 멋있어 보이고 싶으니까
# - 주주클럽 공주병 -
#
# 돈이드니 아무말이나 해 돈이드니 사랑한다 해봐
# 내가 듣기에 좋은 말은 다 해도돼 넌 바보야 넌 너무 답답해
# 너는 정말 분위기 못맞춰 사랑한다고 말해봐 키쓰 해줄께
# 잼있고 즐거운 일이라면 이젠 너와 함께하고 싶어 그런 날 넌 몰라 아무리 설명해도 이해 못해
# 나 오늘 어때 보여 이뻐보여 널 위해 어제산 옷을 입었어
# 넌 매일 똑같은 옷을 입어도 내가 이쁘게 봐줄께
# - 주주 클럽 돈이 드니 -"""
# ```
#
# 위에 보인 하나의 문자열 데이터 안에 '사랑'라는 단어가 있는지 없는지 참 또는 거짓으로 출력하는 코드를 작성하세요.

# %%
lyric = """긴바지를 찢어 입었고 빨간 두건도 지금 쓰고 있어
노랗게 머리 염색을 하고서 모델 같은 표정을 지어 봐도
잡지 속의 이쁜 애들처럼 이뻐보이지 않는 이윤 뭘까
친구들이 이런 말을 해 넌 너무 튀어 보이려 한다고
하지만 난 그런 말 신경안써 난 튀어 보이는게 정말 좋아
난 언제나 나를 믿고 있어 언젠가는 이뻐질 거라고
그래서 난 포기 하지 않아 나는 정말로 멋있어 보이고 싶으니까
- 주주클럽 공주병 -

돈이드니 아무말이나 해 돈이드니 사랑한다 해봐
내가 듣기에 좋은 말은 다 해도돼 넌 바보야 넌 너무 답답해
너는 정말 분위기 못맞춰 사랑한다고 말해봐 키쓰 해줄께
잼있고 즐거운 일이라면 이젠 너와 함께하고 싶어 그런 날 넌 몰라 아무리 설명해도 이해 못해
나 오늘 어때 보여 이뻐보여 널 위해 어제산 옷을 입었어
넌 매일 똑같은 옷을 입어도 내가 이쁘게 봐줄께
- 주주 클럽 돈이 드니 -"""

print( '사랑' in lyric )
# Out:
# True

# %%
#참고
print( lyric.find('긴바지') )
print( lyric.find('사랑') )
print('--- 구분선 ---')

print( lyric.rfind('긴바지') )
print( lyric.rfind('사랑') )
# Out:
# 0
# 244
# --- 구분선 ---
# 0
# 300

# %% [markdown]
# ## 문제 15
# 다음 문자열 데이터를 ', '를 기준으로 분리하여 3개의 문자열로 나누는 코드를 작성하시오.
#
# ```python
# hobby = '드라이브, 낚시, 등산'
# ```

# %% [markdown]
# ###풀이 15-1

# %%
hobby = '드라이브, 낚시, 등산'

hobbys = hobby.split(',')
print( hobbys )
# Out:
# ['드라이브', '낚시', '등산']

# %% [markdown]
# #### 문제 15 응용 문제
#
# ```python
# string = '드라이브, 낚시, 등산/독서, 영화 감상/축구, 농구, 낚시'
# ```
# 위 `string` 문자열을 분리하여 아래와 같은 결과가 나오도록 코드를 작성하시오.
# ```
# ['드라이브', '낚시', '등산', '독서', '영화 감상', '축구', '농구', '낚시']
# ```

# %% [markdown]
# ##### 풀이 - 1

# %%
string = '드라이브, 낚시, 등산/독서, 영화 감상/축구, 농구, 낚시'
string = string.replace('/',',')
print(string.split(','))
# Out:
# ['드라이브', ' 낚시', ' 등산', '독서', ' 영화 감상', '축구', ' 농구', ' 낚시']

# %% [markdown]
# ##문제 16
# 아래 주어진 코드를 보십시요.
#
# ```python
# sdate = '2023:06:28'
# stime = '13-10-25'
# ```
#
# * (1) 날자 정보를 가지고 있는 `sdate`를 '2023-06-28' 형태로 출력하는 코드를 작성 하세요.
# * (2) 시간 정보를 가지고 있는 `stime`를 '13:10:25' 행태로 출력하는 코드를 작성
# 하세요.

# %% [markdown]
# ###풀이 16-(1)-1

# %%
sdate = '2023:06:28'
stime = '13-10-25'

print( sdate.replace(':','-') )
print( stime.replace('-', ':') )
# Out:
# 2023-06-28
# 13:10:25

# %% [markdown]
# ## 문제 17
# 아래 코드를 보십시오. `price1`과 `price2`를 합산한 금액 5,000원을 출력하는 코드를 완성하려고 합니다.
#
# ```python
# price1 = '2,000원'
# price2 = '3,000원'
#
# print( )
# ```
#
# 원하는 출력 형태는 다음과 같읍니다.
# ```
# 5000원
# ```

# %% [markdown]
# ###풀이 17-1

# %%
price1 = '2,000원'
price2 = '3,000원'

price1 = price1.replace('원', '').replace(',', '')
price2 = price2.replace('원', '').replace(',', '')

price1 = float(price1)
price2 = float(price2)

print(price1 + price2, '원')
# Out:
# 5000.0 원

# %%
price1 = '2,000원'
price2 = '3,000원'

price1 = price1.replace('원', '').replace(',', '')
price2 = price2.replace('원', '').replace(',', '')

price1 = int(price1)
price2 = int(price2)

print(price1 + price2, '원')
# Out:
# 5000 원

# %%
price1 = '2,000원'
price2 = '3,000원'

price1 = price1.replace('원', '').replace(',', '')
price2 = price2.replace('원', '').replace(',', '')

price1 = int(price1)
price2 = int(price2)

print(str(price1 + price2)+'원')
# Out:
# 5000원

# %% [markdown]
# ###풀이 17-2

# %%
price1 = '2,000원'
price2 = '3,000원'

value = int (price1.strip('원').replace(',','') ) + int( price2.strip('원').replace(',','') )
print(str(value)+'원')
# Out:
# 5000원

# %% [markdown]
# ###풀이 17-3

# %%
price1 = '2,000원'
price2 = '3,000원'
print('{}원'.format(int(price1.replace(',','')[:4])+int(price2.replace(',','')[:4])))
# Out:
# 5000원

# %% [markdown]
# ####참고

# %%
price1 = '2,000원'
price2 = '3,000원'

price1 = price1.replace('원', '').replace(',', '')
price2 = price2.replace('원', '').replace(',', '')

total = int(price1) + int(price2)

print( format(total, ',') + '원')
# Out:
# 5,000원

# %% [markdown]
# 수고 하셨습니다.
