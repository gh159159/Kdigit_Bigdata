# %% [markdown]
# # 문제 1
# 산 이름에 '악'이라는 글자가 포함된 산을 찾는 코드를 작성하시오
# ```
# a = '도봉산'
# b = '북한산'
# c = '관악산'
# e = '금강산'
# f = '한라산'
# lst = [a, b, c, '주왕산', e, f]
# ```

# %% [markdown]
# # 문제 2
# 사용자로부터 5개의 숫자를 입력 받아 그 숫자 5개를 요소로 하는 리스트를 생성하세요.

# %% [markdown]
# # 문제 3
# 사용자로 부터 임의의 정수 5개를 입력 받습니다. 그 중 짝수만으로 구성된 리스트를 생성하세요.

# %% [markdown]
# # 문제 4
# 아래 보인 리스트 `lst`는 산 이름과 높이를 요소로 하는 리스트를 요소를 갖고 있습니다. 높이가 가장 높은 산의 이름과 높이를 출력하는 코드를 작성하세요.

# %% [markdown]
# # 문제 5
# ```
# lst =[ [1, 2, 'boy'], [True, 3.14], [1, 2, 3, 4, 5, 6]]
# ```
# 위에 보인 리스트를 아래와 같이 출력되도록 코드를 작성하세요.
#
#
# 1 2 boy
# True 3.14
# 1 2 3 4 5 6
