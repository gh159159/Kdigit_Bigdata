# %% [markdown]
# # 돌발 테스트
# 교육 14일째입니다. 약 3주가 경과한 시점입니다. 복습 그리고 스스로 학습 수준를 평가해보기 위해 아래 질문에 성실히 답해주시기 바랍니다.
#
# 제출 마감일시는 오는 일요일(2024년 1월 21일) 오후 5시 전까지입니다. 이 파일에 답안을 작성하셔서 이 메일로 저(phirippa@naver.com)에게 보내주세요.

# %% [markdown]
# ## 1.문제
# 아래 코드를 보고 빈칸에 적절한 코드를 써넣어 전체 코드를 완성하세요.
# ```python
# lst = [0, 1, 2, 3.141592, '4', ['국어:32', '영어:77', '수학:88'], {}, ((1,2), (3, '사', '오')), [] ]
#
# for element in lst:
#   if       or        :
#     print(element)
# ```
# ```
# 0
# 1
# 2
# 3.141592
# ```

# %% [markdown]
# ## 2.문제
# 다음 리스트의 요소 중 수인 요소의 개수와 수가 아닌 요소의 개수를 세는 코드를 작성하세요.

# %%
lst = [1, 3, 5, 'boy', 9, 'girl', {}, 3.14, -200, [1, 2]]

# %% [markdown]
# ## 3.문제
# 아래 코드로 생성된 `lst`에는 어떤 요소가 몇 번 나오는지 카운트하는 코드를 작성하시오.
# ```python
# import random
#
# databanks = ['boy', 'girl', 'cat', 'car', 'ship', 'phirippa', 'apple', 'hello', 'king']
# lst = []
# for _ in range(100):
#   idx = random.randint(0, len(databanks)-1)
#   lst.append(databanks[idx])
# ```

# %% [markdown]
# ## 4. 문제
#
# 아래 코드에 보인 리스트 내포를 일반 for 구문으로 변경하여 동일한 그래프를 그릴 수 있도록 코드를 작성하시오.
# ```python
# def f1(x):
#   return 2*x+1
# def f2(x):
#   return 2*(x**2) + 1
#
# lst = [ f1(x) if x % 2 else f2(x) for x in range(1, 31) ]
#
# import matplotlib.pyplot as plt
# plt.plot(range(1,31), lst, '*:')
# plt.show()
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5.문제
# 이 사이트( https://bit.ly/doit_python )에 접속 합니다. 그러면 Data 폴더가 있습니다. Data 폴더에 있는 exam.csv 파일을 다운로드하여 코랩 파일에서 읽어 올 수 있도록 환경을 조성하십시요.
#
# 먼저 아래 코드 셀을 실행시켜 csv 파일 구조를 파악합니다. 또는 excel 파일로 exam.csv 파일을 열어서 exam.csv 파일의 구조를 살펴 보십시요.
# (단 pandas 모듈을 사용하지 않고 구현하세요.)

# %%
import csv
f = open('exam.csv')
data = csv.reader(f)

for row in data:
  print(row)

f.close()
# Out:
# ['id', 'nclass', 'math', 'english', 'science']
# ['1', '1', '50', '98', '50']
# ['2', '1', '60', '97', '60']
# ['3', '1', '45', '86', '78']
# ['4', '1', '30', '98', '58']
# ['5', '2', '25', '80', '65']
# ['6', '2', '50', '89', '98']
# ['7', '2', '80', '90', '45']
# ['8', '2', '90', '78', '25']
# ['9', '3', '20', '98', '15']
# ['10', '3', '50', '98', '45']
# ['11', '3', '65', '65', '65']
# ['12', '3', '45', '85', '32']
# ['13', '4', '46', '98', '65']
# ['14', '4', '48', '87', '12']
# ['15', '4', '75', '56', '78']
# ['16', '4', '58', '98', '65']
# ['17', '5', '65', '68', '98']
# ['18', '5', '80', '78', '90']
# ['19', '5', '89', '68', '87']
# ['20', '5', '78', '83', '58']

# %% [markdown]
# `'nclass'`는 반을 나타냅니다. 1반부터 5반까지 있군요. 한 학년이 20명인 아담한 학교군요.
#
# - (1) 모든 학생의 수학(`'math'`) 점수를 더해서 수학 총점을 구하는 코드를 작성하세요.
# - (2) 각 반별 수학 총점을 구하는 코드를 작성하세요

# %% [markdown]
# ## 6.문제
# 문제 5에서 사용한 exam.csv 파일을 이용합니다. 각 반에서 1등인 학생의 id를 출력하는 코드를 작성하시요. 즉, 각 반의 1등이 누구인지 id를 출력하는 코드를 작성하세요.

# %% [markdown]
# ## 7.문제
# 학년 전체에서 1등이 누구인지 id를 출력하는 코드를 작성하세요.

# %% [markdown]
# ##8. 문제
# 이 사이트( https://bit.ly/doit_python )에 접속 합니다. 그러면 Data 폴더가 있습니다. Data 폴더에 있는 mpg.csv 파일을 다운로드하여 코랩 파일에서 읽어 올 수 있도록 환경을 조성하십시요.
#
# mpg(mile per gallon)는 미국환경보호국에서 공개한 데이터로 1999~2008년 미국에 출시된 자동차 234종의 정보를 담고 있습니다.
#
# excel 파일로 mpg.csv 파일을 열어서 mpg.csv 파일의 구조를 살펴 보십시요. 그리고 아래 코드를 살펴 본 후 실행시키십시요.

# %%
import csv
f = open('mpg.csv')
data = csv.reader(f)
header = next(data)
data_lst = list(data)
f.close()

print(data_lst[:5])
# Out:
# [['audi', 'a4', '1.8', '1999', '4', 'auto(l5)', 'f', '18', '29', 'p', 'compact'], ['audi', 'a4', '1.8', '1999', '4', 'manual(m5)', 'f', '21', '29', 'p', 'compact'], ['audi', 'a4', '2', '2008', '4', 'manual(m6)', 'f', '20', '31', 'p', 'compact'], ['audi', 'a4', '2', '2008', '4', 'auto(av)', 'f', '21', '30', 'p', 'compact'], ['audi', 'a4', '2.8', '1999', '6', 'auto(l5)', 'f', '16', '26', 'p', 'compact']]

# %%
for data_point in data_lst[0:5]:
  print(data_point)
# Out:
# ['audi', 'a4', '1.8', '1999', '4', 'auto(l5)', 'f', '18', '29', 'p', 'compact']
# ['audi', 'a4', '1.8', '1999', '4', 'manual(m5)', 'f', '21', '29', 'p', 'compact']
# ['audi', 'a4', '2', '2008', '4', 'manual(m6)', 'f', '20', '31', 'p', 'compact']
# ['audi', 'a4', '2', '2008', '4', 'auto(av)', 'f', '21', '30', 'p', 'compact']
# ['audi', 'a4', '2.8', '1999', '6', 'auto(l5)', 'f', '16', '26', 'p', 'compact']

# %% [markdown]
# - (1) 조사 기간 동안 몇 개의 제조회사(manufacturer)가 차량을 출시 했는지 제도회사 수를 파악하는 코드를 작성하세요.
# - (2)  조사 기간 동안 제조 회사 별로 출시 차량(model)이 몇 종류나 되는지 카운트 하는 코드를 작성하세요

# %% [markdown]
# ---

# %% [markdown]
# #  수고 하셨습니다. 주말 무엇이든 신나는 거 하시면서 보내세요.
#
# [여기](https://youtu.be/aRl3PT5Qbwg?si=prK7xbAKmfoUwPPL)는 절대 클릭하지세요.
